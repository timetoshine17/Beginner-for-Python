# %% [markdown]
# <a href="https://colab.research.google.com/github/timetoshine17/Beginner-for-Python/blob/main/huggingface_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
model = AutoModelForSeq2SeqLM.from_pretrained("csebuetnlp/mT5_multilingual_XLSum")
# Out:
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ...

# %%
# 입력 텍스트 준비
text = """
Hugging Face의 mT5_multilingual_XLSum 모델은 여러 언어의 텍스트를 요약하는 데 사용됩니다.
이 모델은 특히 뉴스 데이터 요약에 적합하며, 다양한 언어로 학습되었습니다.
"""

# 입력 텍스트를 모델에 맞게 처리
inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)

# 모델로 요약 생성
summary_ids = model.generate(inputs, max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)

# 생성된 요약 텍스트 디코딩
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

print("요약 결과:")
print(summary)
# Out:
# 요약 결과:
# 'Hugging Face'의 mT5multilingual_XLSum 모델은 BBC 뉴스의 한국어 라디오 소셜 미디어에서 최근 최초로 업데이트됐다.

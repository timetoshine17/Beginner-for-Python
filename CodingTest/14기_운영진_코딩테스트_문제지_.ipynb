# %% [markdown]
# <a href="https://colab.research.google.com/github/timetoshine17/Beginner-for-Python/blob/main/CodingTest/14%EA%B8%B0_%EC%9A%B4%EC%98%81%EC%A7%84_%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8_%EB%AC%B8%EC%A0%9C%EC%A7%80_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이 코딩 테스트는 총 100점 만점이며, 네 개의 섹션으로 구성되어 있습니다. 2부와 3부는 연계되어 있으므로 순서대로 푸는 것을 권장합니다. 1부와 4부는 다른 섹션과 독립적으로 출제되었습니다.
#
# - 테스트를 시작하기 전에 필요한 패키지를 먼저 실행해 주신 후 진행하시면 됩니다.
# - 반드시 .ipynb 파일 형식으로 저장 후 다음의 구글폼으로 제출해 주세요! https://docs.google.com/forms/d/1MeKTUtoUvWv64kRmD2yjMt8xvFF5Q1hcNeyPRs4nhlI/viewform
# - 제출하실 땐 14기_운영진_코딩테스트_문제지_홍길동 과 같이 마지막에 이름도 추가해주세요

# %% [markdown]
# ### 필요 패키지

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1부 : 파이썬, numpy, pandas 기초 (20점)

# %% [markdown]
# 1.1 오늘의 날짜, 자신의 이름, 자신의 생일, MBTI를 리스트로 저장하고 그것을 Series의 형태로 변환하여 출력하세요.(2점)
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.2 정수 n을 기준으로 n과 가까운 수부터 정렬하려고 합니다. 이때 n으로부터의 거리가 같다면 더 큰 수를 앞에 오도록 배치합니다. 정수가 담긴 배열 numlist와 정수 n이 주어질 때 numlist의 원소를 n으로부터 가까운 순서대로 정렬한 배열을 return하도록 solution 함수를 완성해주세요. (3점)
#
# 출력 예시 :
#
# ![image.png](data:image/png;base64,...)

# %%
def solution(numlist, n):
    pass

solution([1, 2, 3, 4, 5, 6], 4)

# %% [markdown]
# 1.3 딕셔너리를 사용하여 다음의 DataFrame 모양을 만들어 출력하세요.(DataFrame은 df로 저장해주세요) (5점)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.4 위에서 만들어진 df의 수학 열 전에 '국어'열을 추가하세요. 학생1의 점수는 95, 학생2의 점수는 85, 학생 3의 점수는 65로 지정해주세요. (5점)
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.5 새로 만들어진 df에 '평균'열을 추가하고, 다섯 과목의 평균 점수를 계산해주세요.(5점)
#
# 출력예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2부 : DataFrame 활용 및 전처리 (40점)

# %% [markdown]
# 2.1 jeju_card.csv 파일을 불러오고 jeju_df 변수에 저장하여 맨 위에 5개 행을 출력하세요. (3점)
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.2 jeju_df에 '연도'열을 새로 추가하고, '연월'열에 저장된 값의 연도만 따로 저장하고 맨 위에 5개 행을 출력하세요. (6점)
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.3 연월 값이 2016이 아닌 데이터만 추출해서 다시 jeju_df에 담아 주세요. (6점)
#
# - 총 16707개의 행이 있어야합니다.

# %% [markdown]
# 2.4 jeju_df의 열 중에서 '연령대'열에서 고유값의 종류와 갯수를 확인해주세요. (4점)
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.5 연령대 컬럼에 '20대미만'과 '20 미만'이란 값이 있습니다. 둘 다 20세 미만의 연령대를 의미하니, '20 미만'을 '20대미만'으로 바꿔 주세요. (6점)

# %% [markdown]
# 2.6 이제 연령대별 카드 이용 현황을 살펴보겠습니다. 먼저, 연령대별로 jeju_df을 묶어주고, 해당 데이터프레임을 grouped_df이란 변수에 저장해주세요. 추가로, 이용금액을 이용자수로 나눠 '인당이용금액'이라는 컬럼을 만든 후, 인당이용금액을 기준으로 내림차순 정렬해서 grouped_df를 출력해주세요. (6점)

# %% [markdown]
# 2.7 이번엔 연령대별 이용금액이 높은 상위 업종 3개를 출력해보겠습니다. '연령대'와 '업종명'을 기준으로 먼저 jeju_df을 묶은 후 grouped_age_sec란 변수에 저장하고, 각 나이대별로 이용금액이 높은 업종 3개를 출력해주시면 됩니다. (9점)
#
# hint:
# - reset_index를 활용
# - for문 활용
#
# 출력 예시:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3부 : 분석 및 시각화 (20점)

# %% [markdown]
# 3.1 이번엔 월별로 카드 이용 금액의 추이를 확인해보겠습니다. 먼저, 연월 기준으로 jeju_df를 묶어주고, 숫자 값들만 가지고 연월별로 합계 구하여 'groupby_ym'란 새로운 데이터프레임에 저장 후 출력해주세요. (10점)
#
# 출력 예시(가독성을 위해 첫 5행만 출력했습니다) :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.2 막대그래프를 이용해 해당 내용을 시각화해 보겠습니다. groupby_ym 데이터를 가지고 X축에는 연월, Y축에는 이용금액이 들어가는 그래프를 그려주세요. 추가로, 그냥 출력하면 X축에 있는 글자들이 다 겹쳐져서 보이는데, pyplot의 xticks라는 함수를 이용하여 90도 돌려주세요. (10점)
# - seaborn(sns)를 사용해주세요
# - 아래 셀은 폰트 설정을 위한 셀입니다. 수정하지 말고 실행시켜주세요.

# %%
# 필요 라이브러리 불러오기
import matplotlib.font_manager as fm
import os

# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum


fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumGothic'}) # 폰트 설정

# %%
#해당 셀에 막대그래프를 그려주세요

# %% [markdown]
# ### 4부 : 자유 분석 (20점)

# %% [markdown]
# 해당 문항은 자유 분석 문항입니다. 필요 패키지에서 'from sklearn import datasets'로 scikit-learn 라이브러리의 데이터셋을 불러왔습니다. 이번 실습으론 해당 라이브러리의 당뇨병 수치 데이터셋을 가져왔으며, X와 y에 각각 입력 변수와 목표 변수를 dataframe으로 바꿔놨습니다. 적절한 모델을 사용하여 y를 분류해주세요(필요 모델에서 LogisticRegression을 이미 불러왔습니다. 해당 모델을 사용하셔도 되고, 다른 모델을 불러와서 사용하셔도 됩니다). 시작코드는 이미 작성이 되어 있습니다. (20점)

# %%
diabetes_dataset = datasets.load_diabetes()

# 입력 변수를 사용하기 편하게 pandas dataframe으로 변환
X = pd.DataFrame(diabetes_dataset.data, columns=diabetes_dataset.feature_names)

# 목표 변수를 사용하기 편하게 pandas dataframe으로 변환
y = pd.DataFrame(diabetes_dataset.target, columns=['diabetes'])

# %%
# 여기 아래에 코드를 작성하세요

## 가이드라인
## 데이터를 train, test로 분할해주세요
## train data를 이용하여 모델을 학습시켜주세요
## test data를 이용하여 모델의 성능을 평가해주세요

# %% [markdown]
# ##END
# 수고하셨습니다.
#
# 다음 구글폼에 .ipynb 파일 형식으로 제출해주세요.
# https://docs.google.com/forms/d/1MeKTUtoUvWv64kRmD2yjMt8xvFF5Q1hcNeyPRs4nhlI/viewform
#
# 좋은 결과 있기를 바라며
# 코딩 테스트는 절대적 평가기준이 아닙니다.
